# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucylucy712/Data_Structure_With_Python/blob/main/Python%20Coding/Exception_Holding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Example 1: Raising an Exception

# %%
import math
import collections
from collections import Iterable

# %%
def sqrt(x):
    if not isinstance(x,(int,float)):
        raise TypeError("x must be numeric")
    elif x<0:
        raise ValueError("x cannot be negative")
    else:
        return (math.sqrt(x))

# %%
def sum(values):
    if not isinstance(values,Iterable):
        raise TypeError("Parameter must be an iterable type")
    total = 0 
    for v in values:
        if not isinstance(v,(int,float)):
            raise TypeError("Elements must be numeric")
        total = total + v 
    return (total)

# %% [markdown]
# ## Example 2: Catching an Exception

# %%
def ratio(x,y):
    try:
        return (x/y)
    except ZeroDivisionError:
        raise ValueError("Y can't be zero")

# %%
ratio(3,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-c17124b8b981> in ratio(x, y)
#       2     try:
# ----> 3         return (x/y)
#       4     except ZeroDivisionError:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-52e73a4775b0> in <module>()
# ----> 1 ratio(3,0)
#
# <ipython-input-23-c17124b8b981> in ratio(x, y)
#       3         return (x/y)
#       4     except ZeroDivisionError:
# ----> 5         raise ValueError("Y can't be zero")
#
# ValueError: Y can't be zero
